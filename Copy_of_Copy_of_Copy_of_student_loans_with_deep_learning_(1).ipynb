# %% [markdown]
# <a href="https://colab.research.google.com/github/zhongzheshen/neural-network-challenge-1/blob/main/Copy_of_Copy_of_Copy_of_student_loans_with_deep_learning_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column

y = loans_df['credit_ranking']

# Display a sample of y
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop('credit_ranking', axis=1)

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
import sklearn as skl

X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler to the features training dataset
X_scaler = X_scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
input_nodes = len(X.columns)

# Review the number of features
input_nodes
# Out:
# 11

# %%
# Define the number of hidden nodes for the first hidden layer
first_hidden_layer_units = 6

# Define the number of hidden nodes for the second hidden layer
second_hidden_layer_units = 3

# Define the number of neurons in the output layer
output_layer_units = 1

# %%
# Create the Sequential model instance
nn_model =tf.keras.models.Sequential()

# Add the first hidden layer
nn_model.add(tf.keras.layers.Dense(units = first_hidden_layer_units, activation = 'relu', input_dim = input_nodes))

# Add the second hidden layer
nn_model.add(tf.keras.layers.Dense(units = second_hidden_layer_units, activation = 'relu'))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_model.add(tf.keras.layers.Dense(units = output_layer_units, activation = 'sigmoid'))

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 6)                 72
#
#  dense_1 (Dense)             (None, 3)                 21
#
#  dense_2 (Dense)             (None, 1)                 4
#
# ...
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 2ms/step - loss: 0.7204 - accuracy: 0.5855
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6639 - accuracy: 0.6222
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6325 - accuracy: 0.6589
# Epoch 4/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6128 - accuracy: 0.6881
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5984 - accuracy: 0.7056
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5867 - accuracy: 0.7189
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5770 - accuracy: 0.7239
# Epoch 8/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5685 - accuracy: 0.7223
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5614 - accuracy: 0.7231
# Epoch 10/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)

# Display the model loss and accuracy results
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# 13/13 - 0s - loss: 0.5316 - accuracy: 0.7150 - 240ms/epoch - 18ms/step
# Loss: 0.531644344329834, Accuracy: 0.7149999737739563

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
file_path = Path('student_loans.keras')

# Export your model to a keras file
nn_model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = Path('student_loans.keras')

# Load the model to a new object
nn_model_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_model.predict(X_test_scaled, verbose=2)

# Display a sample of the predictions
predictions
# Out:
# 13/13 - 0s - 164ms/epoch - 13ms/step
# array([[0.54473877],
#        [0.33934388],
#        [0.9164779 ],
#        [0.5439621 ],
#        [0.9712073 ],
#        [0.86260307],
#        [0.9231869 ],
#        [0.3722627 ],
#        [0.7235229 ],
#        [0.37162465],
#        [0.9421585 ],
#        [0.23628727],
#        [0.2844869 ],
#        [0.91570216],
#        [0.41920933],
#        [0.31521696],
#        [0.90347755],
#        [0.25646347],
#        [0.57831115],
#        [0.40909004],
#        [0.43754035],
#        [0.8735906 ],
#        [0.27459836],
#        [0.9589674 ],
#        [0.39068985],
#        [0.9136955 ],
#        [0.8524127 ],
#        [0.5358909 ],
#        [0.39044514],
#        [0.36622486],
#        [0.473203  ],
#        [0.949735  ],
#        [0.36224657],
#        [0.9292992 ],
#        [0.31433138],
#        [0.3898478 ],
#        [0.19880584],
#        [0.46314833],
#        [0.94016564],
#        [0.18640931],
#        [0.8840508 ],
# ...

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=['predictions'], data=predictions)
predictions_df['predictions'] = round(predictions_df['predictions'], 0)
predictions_df
# Out:
#      predictions
# 0            1.0
# 1            0.0
# 2            1.0
# 3            1.0
# 4            1.0
# ..           ...
# 395          1.0
# 396          0.0
# 397          1.0
# 398          0.0
# 399          1.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df['predictions'].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.76      0.72       188
#            1       0.76      0.67      0.72       212
#
#     accuracy                           0.71       400
#    macro avg       0.72      0.72      0.72       400
# weighted avg       0.72      0.71      0.71       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. The data would need to collected are:
# Student Information - age, gender, location, educational background, field of study, and academic performance. Understanding the student's profile can help tailor loan recommendations to their specific needs and circumstances.
# Financial Information - income, expenses, savings, and existing debts, is crucial for assessing their ability to repay loans. This helps in recommending loan options that align with the student's financial capacity.
# Loan History - previous loans taken by the student, their repayment behavior, and credit history. This helps in recommending suitable loan options based on the student's past borrowing and repayment patterns.
# Interest Rates and Terms - interest rates, repayment terms, fees, and eligibility criteria, etc helps recommending the most suitable loan options for them to easy repay.
# Feedback and Reviews - from other students who have used similar loan products helps to predict current student loans repay rate
# Market Trends - can impact the student loans' repay capability.
#
# The relevance of this data lies in its ability to personalize loan recommendations for individual students based on their unique circumstances and needs. By analyzing student-specific information, financial data, loan history, and market trends, a recommendation system can suggest loan options that are tailored to each student's financial situation, academic pursuits, and repayment capacity. This personalized approach can enhance the student's borrowing experience, increase the likelihood of successful loan repayment, and ultimately contribute to their academic and financial success.
#
# By analyzing student-specific information, financial data, loan history, and market trends, a recommendation system can suggest loan options that are tailored to each student's financial situation, academic pursuits, and repayment capacity.
#
# **2. Context-Based Filtering should be used, because the data we have includes contextual information such as academic background - see columns we have in the dataset, like stem_degree_score, gpa_ranking, time_to_completio, etc
#
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
#
#
# **3. Two real-world challenges that need to be considered while building a recommendation system for student loans are:
#
# 1) No Enough Data - this may lead to inaccurate recommendations
# 2) Security of private information - building a recommendation system needs personal data and finacial information. It is not always easy to convince students to fully trust the system.
